# %%
# ========= Cell 1: 填写任务信息 =========
from datetime import datetime
import ipynbname
task_name = "南部转为CSV"
notebook_name = "barrio_population_calculate2.0.ipynb"  # 不带扩展名
notebook_path = "CASA0004\barrio_population_calculate2.0.ipynb"  # 完整路径
dataset = "2016 JSON & 2016 barrio with pop density"
code_version = "v1.2_G, (2 part of geo cleaning)"
input_dir = r"E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass" #这个文件夹里是mask2form识别结果
geojson_dir = r"E:\Dissertation\CASA0004\barrio_pop_density_clenaed.geojson"    # 这个是geojson
output_dir = r"E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv"   # 输出文件夹
note = "1.把每张图片的fence,wall,Road,Sidewalk,Building,Person,Bicyclist,Motorcyclist,Other Rider,Sky,Vegetation,Street Light这些离散的segement转为比率与计数变量,比率变量：fence,wall,Road,Sidewalk,Building,Sky,Vegetation（在一张图片里面的占比，字段形如\"area_ratio\": 0.310933），计数变量: Person,Bicyclist,Motorcyclist,Other Rider,Street light提取它在一张图片，（一个json里面的出现次数）,json里面的经纬度，upz码等变量请保留，在这一步完成后输出一个csv,一行是一个json的信息2.以barrio名称为group的依据，计算各项在某barrio下的平均值,一个barrio为一行，上述的各个变量为列；按照barrio名匹配geojson（这个json里面有人口数和密度数据）用图片识别输出json里面我整合过的谋杀量去除barrio json里面的population算谋杀率出来，这个是因变量3.在以上分组匹配完成后输出一个能进XGBoost的csv"

# %%
# ========= Cell 1: 转为 CSV 并聚合 =========
import os
import json
import pandas as pd
import geopandas as gpd
from pathlib import Path
os.makedirs(output_dir, exist_ok= True)
# 目标类别映射
ratio_labels = {
    "construction--barrier--fence": "fence_ratio",
    "construction--barrier--wall": "wall_ratio",
    "construction--flat--road": "road_ratio",
    "construction--flat--sidewalk": "sidewalk_ratio",
    "construction--structure--building": "building_ratio",
    "nature--sky": "sky_ratio",
    "nature--vegetation": "vegetation_ratio"
}

count_labels = {
    "human--person": "person_count",
    "human--rider--bicyclist": "bicyclist_count",
    "human--rider--motorcyclist": "motorcyclist_count",
    "human--rider--other-rider": "other_rider_count",
    "object--street-light": "street_light_count"
}

all_csvs = []  # 记录每个子文件夹的 csv 路径

# ========= 遍历子文件夹 =========
for sub_dir in Path(input_dir).iterdir():
    if not sub_dir.is_dir():
        continue
    
    records = []
    for file in sub_dir.glob("*.json"):
        with open(file, "r", encoding="utf-8") as f:
            data = json.load(f)

        record = {
            "image_name": data.get("image_name"),
            "longitude": data.get("longitude"),
            "latitude": data.get("latitude"),
            "barrio": data.get("barrio"),
            "upz_code": data.get("upz_code"),
            "Cantidad": data.get("Cantidad", 0.0)
        }

        for v in ratio_labels.values():
            record[v] = 0.0
        for v in count_labels.values():
            record[v] = 0

        for seg in data.get("segments", []):
            label = seg.get("label_name")
            if label in ratio_labels:
                record[ratio_labels[label]] += seg.get("area_ratio", 0.0)
            if label in count_labels:
                record[count_labels[label]] += 1

        records.append(record)

    if not records:
        continue

    df_sub = pd.DataFrame(records)

    # 保存每个子文件夹一个 CSV
    sub_csv_path = os.path.join(output_dir, f"{sub_dir.name}_features.csv")
    df_sub.to_csv(sub_csv_path, index=False, encoding="utf-8-sig")
    all_csvs.append(sub_csv_path)
    print(f"完成 {sub_dir.name} -> {sub_csv_path}, 共 {len(df_sub)} 行")

# ========= 合并所有子文件夹 CSV =========
dfs = [pd.read_csv(csv) for csv in all_csvs]
df_all = pd.concat(dfs, ignore_index=True)
csv_path = os.path.join(output_dir, "images_features.csv")
df_all.to_csv(csv_path, index=False, encoding="utf-8-sig")
print(f"已输出逐图像特征总表: {csv_path}")

# ========= 按 barrio 聚合 =========
df_grouped = df_all.groupby("barrio").mean(numeric_only=True).reset_index()

gdf = gpd.read_file(geojson_dir)
geo_df = gdf[["barriocomu", "population", "pop_density"]].rename(columns={"barriocomu": "barrio"})

merged = df_grouped.merge(geo_df, on="barrio", how="left")
merged["murder_rate"] = merged["Cantidad"] / merged["population"]

final_csv = os.path.join(output_dir, "barrio_features.csv")
merged.to_csv(final_csv, index=False, encoding="utf-8-sig")
print(f"已输出聚合特征: {final_csv}")
# Out:
# 完成 batch_001 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_001_features.csv, 共 200 行
# 完成 batch_002 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_002_features.csv, 共 200 行
# 完成 batch_003 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_003_features.csv, 共 200 行
# 完成 batch_004 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_004_features.csv, 共 200 行
# 完成 batch_005 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_005_features.csv, 共 200 行
# 完成 batch_006 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_006_features.csv, 共 200 行
# 完成 batch_007 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_007_features.csv, 共 200 行
# 完成 batch_008 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_008_features.csv, 共 200 行
# 完成 batch_009 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_009_features.csv, 共 200 行
# 完成 batch_010 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_010_features.csv, 共 200 行
# 完成 batch_011 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_011_features.csv, 共 200 行
# 完成 batch_012 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_012_features.csv, 共 200 行
# 完成 batch_013 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_013_features.csv, 共 200 行
# 完成 batch_014 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_014_features.csv, 共 200 行
# 完成 batch_015 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_015_features.csv, 共 200 行
# 完成 batch_016 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_016_features.csv, 共 200 行
# 完成 batch_017 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_017_features.csv, 共 200 行
# 完成 batch_018 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_018_features.csv, 共 200 行
# 完成 batch_019 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_019_features.csv, 共 200 行
# 完成 batch_020 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_020_features.csv, 共 200 行
# 完成 batch_021 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_021_features.csv, 共 200 行
# 完成 batch_022 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_022_features.csv, 共 200 行
# 完成 batch_023 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_023_features.csv, 共 200 行
# 完成 batch_024 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_024_features.csv, 共 200 行
# 完成 batch_025 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_025_features.csv, 共 200 行
# 完成 batch_026 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_026_features.csv, 共 200 行
# 完成 batch_027 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_027_features.csv, 共 200 行
# 完成 batch_028 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_028_features.csv, 共 200 行
# 完成 batch_029 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_029_features.csv, 共 200 行
# 完成 batch_030 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_030_features.csv, 共 200 行
# 完成 batch_031 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_031_features.csv, 共 200 行
# 完成 batch_032 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_032_features.csv, 共 200 行
# 完成 batch_033 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_033_features.csv, 共 200 行
# 完成 batch_034 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_034_features.csv, 共 200 行
# 完成 batch_035 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_035_features.csv, 共 200 行
# 完成 batch_036 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_036_features.csv, 共 200 行
# 完成 batch_037 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_037_features.csv, 共 200 行
# 完成 batch_038 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_038_features.csv, 共 200 行
# 完成 batch_039 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_039_features.csv, 共 200 行
# 完成 batch_040 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_040_features.csv, 共 200 行
# 完成 batch_041 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_041_features.csv, 共 200 行
# 完成 batch_042 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_042_features.csv, 共 200 行
# 完成 batch_043 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_043_features.csv, 共 200 行
# 完成 batch_044 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_044_features.csv, 共 200 行
# 完成 batch_045 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_045_features.csv, 共 200 行
# 完成 batch_046 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_046_features.csv, 共 200 行
# 完成 batch_047 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_047_features.csv, 共 200 行
# 完成 batch_048 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_048_features.csv, 共 200 行
# 完成 batch_049 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_049_features.csv, 共 200 行
# 完成 batch_050 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_050_features.csv, 共 200 行
# 完成 batch_051 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_051_features.csv, 共 200 行
# 完成 batch_052 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_052_features.csv, 共 200 行
# 完成 batch_053 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_053_features.csv, 共 200 行
# 完成 batch_054 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_054_features.csv, 共 200 行
# 完成 batch_055 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_055_features.csv, 共 200 行
# 完成 batch_056 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_056_features.csv, 共 200 行
# 完成 batch_057 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_057_features.csv, 共 200 行
# 完成 batch_058 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_058_features.csv, 共 200 行
# 完成 batch_059 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_059_features.csv, 共 200 行
# 完成 batch_060 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_060_features.csv, 共 200 行
# 完成 batch_061 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_061_features.csv, 共 200 行
# 完成 batch_062 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_062_features.csv, 共 200 行
# 完成 batch_063 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_063_features.csv, 共 200 行
# 完成 batch_064 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_064_features.csv, 共 200 行
# 完成 batch_065 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_065_features.csv, 共 200 行
# 完成 batch_066 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_066_features.csv, 共 200 行
# 完成 batch_067 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_067_features.csv, 共 200 行
# 完成 batch_068 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_068_features.csv, 共 200 行
# 完成 batch_069 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_069_features.csv, 共 200 行
# 完成 batch_070 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_070_features.csv, 共 200 行
# 完成 batch_071 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_071_features.csv, 共 200 行
# 完成 batch_072 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_072_features.csv, 共 200 行
# 完成 batch_073 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_073_features.csv, 共 200 行
# 完成 batch_074 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_074_features.csv, 共 200 行
# 完成 batch_075 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_075_features.csv, 共 200 行
# 完成 batch_076 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_076_features.csv, 共 200 行
# 完成 batch_077 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_077_features.csv, 共 200 行
# 完成 batch_078 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_078_features.csv, 共 200 行
# 完成 batch_079 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_079_features.csv, 共 200 行
# 完成 batch_080 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_080_features.csv, 共 200 行
# 完成 batch_081 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_081_features.csv, 共 200 行
# 完成 batch_082 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_082_features.csv, 共 200 行
# 完成 batch_083 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_083_features.csv, 共 200 行
# 完成 batch_084 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_084_features.csv, 共 200 行
# 完成 batch_085 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_085_features.csv, 共 200 行
# 完成 batch_086 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_086_features.csv, 共 200 行
# 完成 batch_087 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_087_features.csv, 共 199 行
# 完成 batch_088 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_088_features.csv, 共 200 行
# 完成 batch_089 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_089_features.csv, 共 200 行
# 完成 batch_090 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_090_features.csv, 共 200 行
# 完成 batch_091 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_091_features.csv, 共 200 行
# 完成 batch_092 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_092_features.csv, 共 200 行
# 完成 batch_093 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_093_features.csv, 共 200 行
# 完成 batch_094 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_094_features.csv, 共 200 行
# 完成 batch_095 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_095_features.csv, 共 200 行
# 完成 batch_096 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_096_features.csv, 共 200 行
# 完成 batch_097 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_097_features.csv, 共 200 行
# 完成 batch_098 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_098_features.csv, 共 200 行
# 完成 batch_099 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_099_features.csv, 共 200 行
# 完成 batch_100 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_100_features.csv, 共 200 行
# 完成 batch_101 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_101_features.csv, 共 200 行
# 完成 batch_102 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_102_features.csv, 共 200 行
# 完成 batch_103 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_103_features.csv, 共 200 行
# 完成 batch_104 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_104_features.csv, 共 200 行
# 完成 batch_105 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_105_features.csv, 共 200 行
# 完成 batch_106 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_106_features.csv, 共 200 行
# 完成 batch_107 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_107_features.csv, 共 200 行
# 完成 batch_108 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_108_features.csv, 共 200 行
# 完成 batch_109 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_109_features.csv, 共 200 行
# 完成 batch_110 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_110_features.csv, 共 200 行
# 完成 batch_111 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_111_features.csv, 共 200 行
# 完成 batch_112 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_112_features.csv, 共 200 行
# 完成 batch_113 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_113_features.csv, 共 200 行
# 完成 batch_114 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_114_features.csv, 共 200 行
# 完成 batch_115 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_115_features.csv, 共 200 行
# 完成 batch_116 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_116_features.csv, 共 200 行
# 完成 batch_117 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_117_features.csv, 共 200 行
# 完成 batch_118 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_118_features.csv, 共 200 行
# 完成 batch_119 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_119_features.csv, 共 200 行
# 完成 batch_120 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_120_features.csv, 共 200 行
# 完成 batch_121 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_121_features.csv, 共 200 行
# 完成 batch_122 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_122_features.csv, 共 200 行
# 完成 batch_123 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_123_features.csv, 共 200 行
# 完成 batch_124 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_124_features.csv, 共 200 行
# 完成 batch_125 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_125_features.csv, 共 200 行
# 完成 batch_126 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_126_features.csv, 共 200 行
# 完成 batch_127 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_127_features.csv, 共 200 行
# 完成 batch_128 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_128_features.csv, 共 200 行
# 完成 batch_129 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_129_features.csv, 共 200 行
# 完成 batch_130 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_130_features.csv, 共 200 行
# 完成 batch_131 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_131_features.csv, 共 200 行
# 完成 batch_132 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_132_features.csv, 共 200 行
# 完成 batch_133 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_133_features.csv, 共 200 行
# 完成 batch_134 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_134_features.csv, 共 200 行
# 完成 batch_135 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_135_features.csv, 共 200 行
# 完成 batch_136 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_136_features.csv, 共 200 行
# 完成 batch_137 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_137_features.csv, 共 200 行
# 完成 batch_138 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_138_features.csv, 共 200 行
# 完成 batch_139 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_139_features.csv, 共 200 行
# 完成 batch_140 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_140_features.csv, 共 200 行
# 完成 batch_141 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_141_features.csv, 共 200 行
# 完成 batch_142 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_142_features.csv, 共 200 行
# 完成 batch_143 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_143_features.csv, 共 200 行
# 完成 batch_144 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_144_features.csv, 共 200 行
# 完成 batch_145 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_145_features.csv, 共 200 行
# 完成 batch_146 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_146_features.csv, 共 200 行
# 完成 batch_147 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_147_features.csv, 共 200 行
# 完成 batch_148 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_148_features.csv, 共 200 行
# 完成 batch_149 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_149_features.csv, 共 200 行
# 完成 batch_150 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_150_features.csv, 共 200 行
# 完成 batch_151 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_151_features.csv, 共 200 行
# 完成 batch_152 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_152_features.csv, 共 200 行
# 完成 batch_153 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_153_features.csv, 共 200 行
# 完成 batch_154 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_154_features.csv, 共 200 行
# 完成 batch_155 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_155_features.csv, 共 200 行
# 完成 batch_156 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_156_features.csv, 共 200 行
# 完成 batch_157 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_157_features.csv, 共 200 行
# 完成 batch_158 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_158_features.csv, 共 200 行
# 完成 batch_159 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_159_features.csv, 共 200 行
# 完成 batch_160 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_160_features.csv, 共 200 行
# 完成 batch_161 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_161_features.csv, 共 200 行
# 完成 batch_162 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_162_features.csv, 共 200 行
# 完成 batch_163 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_163_features.csv, 共 200 行
# 完成 batch_164 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_164_features.csv, 共 200 行
# 完成 batch_165 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_165_features.csv, 共 200 行
# 完成 batch_166 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_166_features.csv, 共 200 行
# 完成 batch_167 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_167_features.csv, 共 200 行
# 完成 batch_168 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_168_features.csv, 共 200 行
# 完成 batch_169 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_169_features.csv, 共 200 行
# 完成 batch_170 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_170_features.csv, 共 200 行
# 完成 batch_171 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_171_features.csv, 共 200 行
# 完成 batch_172 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_172_features.csv, 共 200 行
# 完成 batch_173 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_173_features.csv, 共 200 行
# 完成 batch_174 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_174_features.csv, 共 200 行
# 完成 batch_175 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_175_features.csv, 共 200 行
# 完成 batch_176 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_176_features.csv, 共 200 行
# 完成 batch_177 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_177_features.csv, 共 200 行
# 完成 batch_178 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_178_features.csv, 共 200 行
# 完成 batch_179 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_179_features.csv, 共 200 行
# 完成 batch_180 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_180_features.csv, 共 200 行
# 完成 batch_181 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_181_features.csv, 共 200 行
# 完成 batch_182 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_182_features.csv, 共 200 行
# 完成 batch_183 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_183_features.csv, 共 200 行
# 完成 batch_184 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_184_features.csv, 共 200 行
# 完成 batch_185 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_185_features.csv, 共 200 行
# 完成 batch_186 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_186_features.csv, 共 200 行
# 完成 batch_187 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_187_features.csv, 共 200 行
# 完成 batch_188 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_188_features.csv, 共 200 行
# 完成 batch_189 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_189_features.csv, 共 200 行
# 完成 batch_190 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_190_features.csv, 共 200 行
# 完成 batch_191 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_191_features.csv, 共 200 行
# 完成 batch_192 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_192_features.csv, 共 200 行
# 完成 batch_193 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_193_features.csv, 共 200 行
# 完成 batch_194 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_194_features.csv, 共 200 行
# 完成 batch_195 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_195_features.csv, 共 200 行
# 完成 batch_196 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_196_features.csv, 共 200 行
# 完成 batch_197 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_197_features.csv, 共 200 行
# 完成 batch_198 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_198_features.csv, 共 200 行
# 完成 batch_199 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_199_features.csv, 共 200 行
# 完成 batch_200 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_200_features.csv, 共 200 行
# 完成 batch_201 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_201_features.csv, 共 200 行
# 完成 batch_202 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_202_features.csv, 共 200 行
# 完成 batch_203 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_203_features.csv, 共 200 行
# 完成 batch_204 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_204_features.csv, 共 200 行
# 完成 batch_205 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_205_features.csv, 共 200 行
# 完成 batch_206 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_206_features.csv, 共 200 行
# 完成 batch_207 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_207_features.csv, 共 200 行
# 完成 batch_208 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_208_features.csv, 共 200 行
# 完成 batch_209 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_209_features.csv, 共 200 行
# 完成 batch_210 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_210_features.csv, 共 200 行
# 完成 batch_211 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_211_features.csv, 共 200 行
# 完成 batch_212 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_212_features.csv, 共 200 行
# 完成 batch_213 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_213_features.csv, 共 200 行
# 完成 batch_214 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_214_features.csv, 共 200 行
# 完成 batch_215 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_215_features.csv, 共 200 行
# 完成 batch_216 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_216_features.csv, 共 200 行
# 完成 batch_217 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_217_features.csv, 共 200 行
# 完成 batch_218 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_218_features.csv, 共 200 行
# 完成 batch_219 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_219_features.csv, 共 200 行
# 完成 batch_220 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_220_features.csv, 共 200 行
# 完成 batch_221 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_221_features.csv, 共 200 行
# 完成 batch_222 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_222_features.csv, 共 200 行
# 完成 batch_223 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_223_features.csv, 共 200 行
# 完成 batch_224 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_224_features.csv, 共 200 行
# 完成 batch_225 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_225_features.csv, 共 200 行
# 完成 batch_226 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_226_features.csv, 共 200 行
# 完成 batch_227 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_227_features.csv, 共 200 行
# 完成 batch_228 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_228_features.csv, 共 200 行
# 完成 batch_229 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_229_features.csv, 共 200 行
# 完成 batch_230 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_230_features.csv, 共 200 行
# 完成 batch_231 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_231_features.csv, 共 200 行
# 完成 batch_232 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_232_features.csv, 共 200 行
# 完成 batch_233 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_233_features.csv, 共 200 行
# 完成 batch_234 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_234_features.csv, 共 200 行
# 完成 batch_235 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_235_features.csv, 共 200 行
# 完成 batch_236 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_236_features.csv, 共 200 行
# 完成 batch_237 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_237_features.csv, 共 200 行
# 完成 batch_238 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_238_features.csv, 共 200 行
# 完成 batch_239 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_239_features.csv, 共 200 行
# 完成 batch_240 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_240_features.csv, 共 200 行
# 完成 batch_241 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_241_features.csv, 共 200 行
# 完成 batch_242 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_242_features.csv, 共 200 行
# 完成 batch_243 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_243_features.csv, 共 200 行
# 完成 batch_244 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_244_features.csv, 共 200 行
# 完成 batch_245 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_245_features.csv, 共 200 行
# 完成 batch_246 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_246_features.csv, 共 200 行
# 完成 batch_247 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_247_features.csv, 共 200 行
# 完成 batch_248 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_248_features.csv, 共 200 行
# 完成 batch_249 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_249_features.csv, 共 200 行
# 完成 batch_250 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_250_features.csv, 共 200 行
# 完成 batch_251 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_251_features.csv, 共 200 行
# 完成 batch_252 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_252_features.csv, 共 200 行
# 完成 batch_253 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_253_features.csv, 共 200 行
# 完成 batch_254 -> E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\batch_254_features.csv, 共 165 行
# 已输出逐图像特征总表: E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\images_features.csv
# 已输出聚合特征: E:\Dissertation\XGBoost_cleaning\2016north_Mask2Former_with_geobarriokilling_SelectedSegClass_Transtocsv\barrio_features.csv

# %%
# ===== 记录日志 =====
current_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
def append_log(task_name, dataset, code_version, input_dir, output_dir, status, duration, note):
    repo_dir = 'E:\Dissertation\CASA0004'
    log_path = f"{repo_dir}/operation_log.md"

    # 写入日志
    with open(log_path, "a", encoding="utf-8") as f:
        f.write(f"**任务名称**: {task_name}\n")
        f.write(f"**任务文件**: {notebook_name}\n")
        f.write(f"**文件路径**: {notebook_path}\n")
        f.write(f"**数据集**: {dataset}\n")
        f.write(f"**代码版本**: {code_version}\n")
        f.write(f"**输入目录**: {input_dir}\n")
        f.write(f"**输出目录**: {output_dir}\n")
        f.write(f"**状态**: {status}\n")
        f.write(f"**耗时**: {duration}\n")
        f.write(f"**备注**: {note}\n")
        f.write(f"**记录时间**: {current_time}\n\n")
        f.write("================分割线================\n\n")

    print("✅ 日志写入完成")
status="完成，只输出了当前区块的brrio"
duration = "50s"
append_log(task_name, dataset, code_version, input_dir, output_dir, status, duration, note)
# Out:
# ✅ 日志写入完成
# <>:4: SyntaxWarning: invalid escape sequence '\D'
# <>:4: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\wengqc\AppData\Local\Temp\ipykernel_5012\2122369284.py:4: SyntaxWarning: invalid escape sequence '\D'
#   repo_dir = 'E:\Dissertation\CASA0004'
